# %%
import pandas as pd

data = pd.read_json('C:\Coding\Python\Data\Dragon of Icespire Peak Chat Logs.json')
data.head()
# Out:
#                 _id  type              user               timestamp  \
# 0  AIA6IOoiF3gMfWDS     0  YTM0YTBiNTMyMTgy 2020-07-04 21:54:27.517
# 1  Yfj2BTQVvkIpNXa5     5  YTM0YTBiNTMyMTgy 2020-07-04 21:54:53.891
# 2  GEcNLIxhZ0aXiG7U     5  YTM0YTBiNTMyMTgy 2020-07-04 21:56:24.210
# 3  ntcTlwopgw6jBPNz     5  YTM0YTBiNTMyMTgy 2020-07-04 21:57:02.470
# 4  VfDoX0ExPXNRQYEl     5  FPEl1kfEtrq9GYC9 2020-07-04 21:58:52.068
#
#                                              content  \
# 0  <div class="dnd5e chat-card item-card" data-ac...
# 1                                                  6
# 2                                                 16
# 3                                                 17
# 4                                             1d20+3
#
#                                              speaker  \
# 0  {'actor': 'NDk0YTJkNGNhODdi', 'token': 'ZjRlOD...
# 1  {'scene': 'MDA3YzhmYzYwNjhl', 'actor': 'NDk0YT...
# 2  {'scene': 'MDA3YzhmYzYwNjhl', 'actor': 'NDk0YT...
# ...
